# %%
a = float(input('Give a number: '))
a = a - int(a)
r = -1
b = []
while a > 10**(-5):
    if a >= 2**r:
        b.append('1')
        a = a - 2**r
    else:
        b.append('0')
    r -= 1
print('Υπόλοιπο a = ',a)
print('r = ',r)
print(b)
print(''.join(b))
